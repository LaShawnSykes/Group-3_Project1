# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# Load the datasets
data_t1dm = pd.read_excel('C:/Users/revcr/Proxy/Project 01/Group-3_Project1/Datasets/Shanghai_T1DM_Summary.xlsx')
data_t2dm = pd.read_excel('C:/Users/revcr/Proxy/Project 01/Group-3_Project1/Datasets/Shanghai_T2DM_Summary.xlsx')

df1 = data_t1dm
df2 = data_t2dm

# %%
df2
# Out:
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0    2000_0_20201230                          2           57        1.69
# 1    2001_0_20201102                          1           69        1.45
# 2    2001_1_20201117                          1           69        1.45
# 3    2002_0_20210513                          2           57        1.70
# 4    2003_0_20210615                          1           58        1.64
# ..               ...                        ...          ...         ...
# 104  2095_0_20201116                          2           66        1.72
# 105  2096_0_20201116                          1           60        1.57
# 106  2097_0_20201116                          1           71        1.70
# 107  2098_0_20201106                          1           64        1.60
# 108  2099_0_20201116                          1           44        1.52
#
#      Weight (kg)  BMI (kg/m2)  Smoking History (pack year)  \
# ...

# %%
display(df1)
# Out:
#      Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0   1001_0_20210730                          1           66        1.50
# 1   1002_0_20210504                          2           68        1.70
# 2   1002_1_20210521                          2           68        1.70
# 3   1002_2_20210909                          2           68        1.70
# 4   1003_0_20210831                          2           37        1.90
# 5   1004_0_20210425                          1           67        1.55
# 6   1005_0_20210522                          2           58        1.70
# 7   1006_0_20210114                          2           57        1.61
# 8   1006_1_20210209                          2           57        1.61
# 9   1006_2_20210303                          2           57        1.60
# 10  1007_0_20210726                          2           40        1.78
# 11  1008_0_20210713                          1           73        1.61
# ...

# %%
#Get information about dataset 1
df1.info
# Out:
# <bound method DataFrame.info of      Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0   1001_0_20210730                          1           66        1.50
# 1   1002_0_20210504                          2           68        1.70
# 2   1002_1_20210521                          2           68        1.70
# 3   1002_2_20210909                          2           68        1.70
# 4   1003_0_20210831                          2           37        1.90
# 5   1004_0_20210425                          1           67        1.55
# 6   1005_0_20210522                          2           58        1.70
# 7   1006_0_20210114                          2           57        1.61
# 8   1006_1_20210209                          2           57        1.61
# 9   1006_2_20210303                          2           57        1.60
# 10  1007_0_20210726                          2           40        1.78
# 11  1008_0_20210713                          1           73        1.61
# ...

# %%
#Get information about dataset 2
df2.info
# Out:
# <bound method DataFrame.info of       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0    2000_0_20201230                          2           57        1.69
# 1    2001_0_20201102                          1           69        1.45
# 2    2001_1_20201117                          1           69        1.45
# 3    2002_0_20210513                          2           57        1.70
# 4    2003_0_20210615                          1           58        1.64
# ..               ...                        ...          ...         ...
# 104  2095_0_20201116                          2           66        1.72
# 105  2096_0_20201116                          1           60        1.57
# 106  2097_0_20201116                          1           71        1.70
# 107  2098_0_20201106                          1           64        1.60
# 108  2099_0_20201116                          1           44        1.52
#
# ...

# %%
# Compare the shapes of the two DataFrames
if df1.shape == df2.shape:
    print("The shapes of the DataFrames are the same.")
else:
    print("The shapes of the DataFrames are different.")
# Out:
# The shapes of the DataFrames are different.

# %%
# Compare the data in the two DataFrames
data_equal = df1.equals(df2)
if data_equal:
    print("The data in the DataFrames is the same.")
else:
    print("The data in the DataFrames is different.")
# Out:
# The data in the DataFrames is different.

# %%
# Displaying the columns of df1
print("Columns of df1:")
print(df1.columns)

# Displaying the columns of df2
print("\nColumns of df2:")
print(df2.columns)
# Out:
# Columns of df1:
# Index(['Patient Number', 'Gender (Female=1, Male=2)', 'Age (years)',
#        'Height (m)', 'Weight (kg)', 'BMI (kg/m2)',
#        'Smoking History (pack year)',
#        'Alcohol Drinking History (drinker/non-drinker)', 'Type of Diabetes',
#        'Duration of Diabetes  (years)', 'Acute Diabetic Complications',
#        'Diabetic Macrovascular  Complications',
#        'Diabetic Microvascular Complications', 'Comorbidities',
#        'Hypoglycemic Agents', 'Other Agents', 'Fasting Plasma Glucose (mg/dl)',
#        '2-hour Postprandial Plasma Glucose (mg/dl)',
#        'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
#        'Fasting Insulin (pmol/L)', '2-hour Postprandial Insulin (pmol/L)',
#        'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
#        'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
#        'High-Density Lipoprotein Cholesterol (mmol/L)',
# ...

# %%
# Displaying the row headers of df1
print("Row headers of df1:")
print(df1.index)

# Displaying the row headers of df2
print("\nRow headers of df2:")
print(df2.index)
# Out:
# Row headers of df1:
# RangeIndex(start=0, stop=16, step=1)
#
# Row headers of df2:
# RangeIndex(start=0, stop=109, step=1)

# %%
# Concatenating the DataFrames while preserving row headers and column names
result = pd.concat([df1, df2])

# Displaying the concatenated DataFrame
print(result)
# Out:
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0    1001_0_20210730                          1           66        1.50
# 1    1002_0_20210504                          2           68        1.70
# 2    1002_1_20210521                          2           68        1.70
# 3    1002_2_20210909                          2           68        1.70
# 4    1003_0_20210831                          2           37        1.90
# ..               ...                        ...          ...         ...
# 104  2095_0_20201116                          2           66        1.72
# 105  2096_0_20201116                          1           60        1.57
# 106  2097_0_20201116                          1           71        1.70
# 107  2098_0_20201106                          1           64        1.60
# 108  2099_0_20201116                          1           44        1.52
#
#      Weight (kg)  BMI (kg/m2)  Smoking History (pack year)  \
# ...

# %%
# Define the file path to save the Excel file
file_path = 'C:/Users/revcr/Proxy/Project 01/Group-3_Project1/Datasets/concatenated_data.xlsx'

# Exporting the concatenated DataFrame to the specified file path
result.to_excel(file_path, index=False)

# %%
df3 = result

# %%
df3
# Out:
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0    1001_0_20210730                          1           66        1.50
# 1    1002_0_20210504                          2           68        1.70
# 2    1002_1_20210521                          2           68        1.70
# 3    1002_2_20210909                          2           68        1.70
# 4    1003_0_20210831                          2           37        1.90
# ..               ...                        ...          ...         ...
# 104  2095_0_20201116                          2           66        1.72
# 105  2096_0_20201116                          1           60        1.57
# 106  2097_0_20201116                          1           71        1.70
# 107  2098_0_20201106                          1           64        1.60
# 108  2099_0_20201116                          1           44        1.52
#
#      Weight (kg)  BMI (kg/m2)  Smoking History (pack year)  \
# ...

# %%
# Check for missing values in the DataFrame
missing_values = df3.isnull().sum()
print("Missing values in the DataFrame:")
print(missing_values)
# Out:
# Missing values in the DataFrame:
# Patient Number                                              0
# Gender (Female=1, Male=2)                                   0
# Age (years)                                                 0
# Height (m)                                                  0
# Weight (kg)                                                 0
# BMI (kg/m2)                                                 0
# Smoking History (pack year)                                 0
# Alcohol Drinking History (drinker/non-drinker)              0
# Type of Diabetes                                            0
# Duration of Diabetes  (years)                             109
# Acute Diabetic Complications                                0
# Diabetic Macrovascular  Complications                       0
# Diabetic Microvascular Complications                        0
# Comorbidities                                               0
# Hypoglycemic Agents                                         0
# ...

# %%
print(df3.dtypes)
# Out:
# Patient Number                                             object
# Gender (Female=1, Male=2)                                   int64
# Age (years)                                                 int64
# Height (m)                                                float64
# Weight (kg)                                               float64
# BMI (kg/m2)                                               float64
# Smoking History (pack year)                               float64
# Alcohol Drinking History (drinker/non-drinker)             object
# Type of Diabetes                                           object
# Duration of Diabetes  (years)                             float64
# Acute Diabetic Complications                               object
# Diabetic Macrovascular  Complications                      object
# Diabetic Microvascular Complications                       object
# Comorbidities                                              object
# ...

# %%
# Calculate the mean of 'Duration of Diabetes (years)' for the rows with the condition 'T1DM'
mean_duration_t1dm = df3[df3['Type of Diabetes'] == 'T1DM']['Duration of diabetes (years)'].mean()

# Insert the derived mean into the null values of 'Duration of Diabetes' for rows with the condition 'T1DM'
df3.loc[df3['Type of Diabetes'] == 'T1DM', 'Duration of diabetes (years)'].fillna(mean_duration_t1dm, inplace=True)

# Display the 'Duration of Diabetes (years)' column
print(df3['Duration of diabetes (years)'])
df3.head(17)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 104     7.0
# 105     0.1
# 106    20.0
# 107     0.1
# 108     0.1
# Name: Duration of diabetes (years), Length: 125, dtype: float64
#      Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0   1001_0_20210730                          1           66        1.50
# 1   1002_0_20210504                          2           68        1.70
# 2   1002_1_20210521                          2           68        1.70
# 3   1002_2_20210909                          2           68        1.70
# 4   1003_0_20210831                          2           37        1.90
# 5   1004_0_20210425                          1           67        1.55
# 6   1005_0_20210522                          2           58        1.70
# 7   1006_0_20210114                          2           57        1.61
# 8   1006_1_20210209                          2           57        1.61
# ...

# %%
# Calculate the mean of 'Duration of Diabetes (years)' for the rows with the condition 'T1DM'
mean_duration_t2dm = df3[df3['Type of Diabetes'] == 'T2DM']['Duration of diabetes (years)'].mean()

# Insert the derived mean into the null values of 'Duration of Diabetes' for rows with the condition 'T2DM'
#df3.loc[df3['Type of Diabetes'] == 'T2DM', 'Duration of diabetes (years)'].fillna(mean_duration_t2dm, inplace=True)

print(df3['Duration of diabetes (years)'])
df3.tail(-90)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 104     7.0
# 105     0.1
# 106    20.0
# 107     0.1
# 108     0.1
# Name: Duration of diabetes (years), Length: 125, dtype: float64
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 74   2069_0_20210621                          1           85       1.500
# 75   2069_1_20210705                          1           85       1.500
# 76   2069_2_20210825                          1           85       1.500
# 77   2070_0_20210629                          2           62       1.760
# 78   2071_0_20210705                          2           63       1.700
# 79   2072_0_20210706                          2           59       1.650
# 80   2073_0_20210703                          2           97       1.760
# 81   2074_0_20210707                          2           31       1.800
# 82   2074_1_20210720                          2           31       1.800
# ...

# %%
# Calculate the mean of 'Duration of Diabetes (years)' for the rows with the condition 'T2DM'
mean_duration_t2dm = df3.loc[df3['Type of Diabetes'] == 'T2DM', 'Duration of diabetes (years)'].mean()

# Replace the NaN values with the mean for rows with the condition 'T2DM'
df3.loc[df3['Type of Diabetes'] == 'T2DM','Duration of diabetes (years)'] = df3.loc[df3['Type of Diabetes'] == 'T2DM', 'Duration of diabetes (years)'].fillna(mean_duration_t2dm)


print(df3['Duration of diabetes (years)'])
df3.tail(-90)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 104     7.0
# 105     0.1
# 106    20.0
# 107     0.1
# 108     0.1
# Name: Duration of diabetes (years), Length: 125, dtype: float64
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 74   2069_0_20210621                          1           85       1.500
# 75   2069_1_20210705                          1           85       1.500
# 76   2069_2_20210825                          1           85       1.500
# 77   2070_0_20210629                          2           62       1.760
# 78   2071_0_20210705                          2           63       1.700
# 79   2072_0_20210706                          2           59       1.650
# 80   2073_0_20210703                          2           97       1.760
# 81   2074_0_20210707                          2           31       1.800
# 82   2074_1_20210720                          2           31       1.800
# ...

# %%
print(df3.columns)
# Out:
# Index(['Patient Number', 'Gender (Female=1, Male=2)', 'Age (years)',
#        'Height (m)', 'Weight (kg)', 'BMI (kg/m2)',
#        'Smoking History (pack year)',
#        'Alcohol Drinking History (drinker/non-drinker)', 'Type of Diabetes',
#        'Duration of Diabetes  (years)', 'Acute Diabetic Complications',
#        'Diabetic Macrovascular  Complications',
#        'Diabetic Microvascular Complications', 'Comorbidities',
#        'Hypoglycemic Agents', 'Other Agents', 'Fasting Plasma Glucose (mg/dl)',
#        '2-hour Postprandial Plasma Glucose (mg/dl)',
#        'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
#        'Fasting Insulin (pmol/L)', '2-hour Postprandial Insulin (pmol/L)',
#        'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
#        'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
#        'High-Density Lipoprotein Cholesterol (mmol/L)',
#        'Low-Density Lipoprotein Cholesterol (mmol/L)', 'Creatinine (umol/L)',
# ...

# %%
# Assuming df3 is the DataFrame containing the columns "Duration of Diabetes (years)" and "Duration of diabetes (years)"
# Merge the columns and handle NaN values
df3['Merge DoD (years)'] = df3['Duration of Diabetes  (years)'].fillna(df3['Duration of diabetes (years)'])

# %%
print(df3.columns)
# Out:
# Index(['Patient Number', 'Gender (Female=1, Male=2)', 'Age (years)',
#        'Height (m)', 'Weight (kg)', 'BMI (kg/m2)',
#        'Smoking History (pack year)',
#        'Alcohol Drinking History (drinker/non-drinker)', 'Type of Diabetes',
#        'Duration of Diabetes  (years)', 'Acute Diabetic Complications',
#        'Diabetic Macrovascular  Complications',
#        'Diabetic Microvascular Complications', 'Comorbidities',
#        'Hypoglycemic Agents', 'Other Agents', 'Fasting Plasma Glucose (mg/dl)',
#        '2-hour Postprandial Plasma Glucose (mg/dl)',
#        'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
#        'Fasting Insulin (pmol/L)', '2-hour Postprandial Insulin (pmol/L)',
#        'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
#        'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
#        'High-Density Lipoprotein Cholesterol (mmol/L)',
#        'Low-Density Lipoprotein Cholesterol (mmol/L)', 'Creatinine (umol/L)',
# ...

# %%
# Remove the 'Duration of Diabetes (years)' and 'Duration of diabetes (years)' columns
df3 = df3.drop(['Duration of Diabetes  (years)', 'Duration of diabetes (years)'], axis=1)

# %%
print(df3.columns)
# Out:
# Index(['Patient Number', 'Gender (Female=1, Male=2)', 'Age (years)',
#        'Height (m)', 'Weight (kg)', 'BMI (kg/m2)',
#        'Smoking History (pack year)',
#        'Alcohol Drinking History (drinker/non-drinker)', 'Type of Diabetes',
#        'Acute Diabetic Complications', 'Diabetic Macrovascular  Complications',
#        'Diabetic Microvascular Complications', 'Comorbidities',
#        'Hypoglycemic Agents', 'Other Agents', 'Fasting Plasma Glucose (mg/dl)',
#        '2-hour Postprandial Plasma Glucose (mg/dl)',
#        'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
#        'Fasting Insulin (pmol/L)', '2-hour Postprandial Insulin (pmol/L)',
#        'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
#        'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
#        'High-Density Lipoprotein Cholesterol (mmol/L)',
#        'Low-Density Lipoprotein Cholesterol (mmol/L)', 'Creatinine (umol/L)',
# ...

# %%
df3.drop_duplicates(inplace=True)

# %%
print(df3)
# Out:
#       Patient Number  Gender (Female=1, Male=2)  Age (years)  Height (m)  \
# 0    1001_0_20210730                          1           66        1.50
# 1    1002_0_20210504                          2           68        1.70
# 2    1002_1_20210521                          2           68        1.70
# 3    1002_2_20210909                          2           68        1.70
# 4    1003_0_20210831                          2           37        1.90
# ..               ...                        ...          ...         ...
# 104  2095_0_20201116                          2           66        1.72
# 105  2096_0_20201116                          1           60        1.57
# 106  2097_0_20201116                          1           71        1.70
# 107  2098_0_20201106                          1           64        1.60
# 108  2099_0_20201116                          1           44        1.52
#
#      Weight (kg)  BMI (kg/m2)  Smoking History (pack year)  \
# ...

# %%
df3_clean = df3

# %%
# Define the file path to save the Excel file
file_path = 'C:/Users/revcr/Proxy/Project 01/Group-3_Project1/Datasets/clean_data.xlsx'

# Exporting the clean DataFrame to the specified file path
df3_clean.to_excel(file_path, index=False)

# %%
df3_clean.columns
# Out:
# Index(['Patient Number', 'Gender (Female=1, Male=2)', 'Age (years)',
#        'Height (m)', 'Weight (kg)', 'BMI (kg/m2)',
#        'Smoking History (pack year)',
#        'Alcohol Drinking History (drinker/non-drinker)', 'Type of Diabetes',
#        'Acute Diabetic Complications', 'Diabetic Macrovascular  Complications',
#        'Diabetic Microvascular Complications', 'Comorbidities',
#        'Hypoglycemic Agents', 'Other Agents', 'Fasting Plasma Glucose (mg/dl)',
#        '2-hour Postprandial Plasma Glucose (mg/dl)',
#        'Fasting C-peptide (nmol/L)', '2-hour Postprandial C-peptide (nmol/L)',
#        'Fasting Insulin (pmol/L)', '2-hour Postprandial Insulin (pmol/L)',
#        'HbA1c (mmol/mol)', 'Glycated Albumin (%)',
#        'Total Cholesterol (mmol/L)', 'Triglyceride (mmol/L)',
#        'High-Density Lipoprotein Cholesterol (mmol/L)',
#        'Low-Density Lipoprotein Cholesterol (mmol/L)', 'Creatinine (umol/L)',
# ...

# %%
df3_clean.dtypes
# Out:
# Patient Number                                             object
# Gender (Female=1, Male=2)                                   int64
# Age (years)                                                 int64
# Height (m)                                                float64
# Weight (kg)                                               float64
# BMI (kg/m2)                                               float64
# Smoking History (pack year)                               float64
# Alcohol Drinking History (drinker/non-drinker)             object
# Type of Diabetes                                           object
# Acute Diabetic Complications                               object
# Diabetic Macrovascular  Complications                      object
# Diabetic Microvascular Complications                       object
# Comorbidities                                              object
# Hypoglycemic Agents                                        object
# ...

# %%
#Looking for coorelations between different columns. In this example its a comparisson of age factor vs weight.

plt.scatter(df3_clean.iloc[:,3],df3_clean.iloc[:,5])
plt.xlabel('Age (years)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
# Handling outliers
# Use statistical methods to identify and handle outliers in the data

# Identify and handle outliers using statistical methods (e.g., Z-score, IQR)

# Feature engineering
# Create new features from existing data if needed

# Create a new feature based on existing data
# Example: Create a new feature by combining existing columns
#df3['new_feature'] = df3['column1'] * df3['column2']

# %%
# After doing some research on diabetes to help understand the different variables at play, here are some suggestions on what new data we could make.

# %%
# Body Mass Index (BMI) Category: A new feature based on BMI ranges.

def categorize_bmi(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 25:
        return 'Normal Weight'
    elif 25 <= bmi < 30:
        return 'Overweight'
    else:
        return 'Obese'

df3['BMI Category'] = df3['BMI (kg/m2)'].apply(categorize_bmi)

# %%
#Total Daily Insulin Dose: Utilizing data on both fasting and postprandial insulin levels, we can calculate the total daily insulin dose:
#First convert to float or int, then run calculation.

df3['Fasting Insulin (pmol/L)'] = pd.to_numeric(df3['Fasting Insulin (pmol/L)'], errors='coerce')
df3['2-hour Postprandial Insulin (pmol/L)'] = pd.to_numeric(df3['2-hour Postprandial Insulin (pmol/L)'], errors='coerce')
df3['Total Daily Insulin Dose (pmol/L)'] = (df3['Fasting Insulin (pmol/L)'] + df3['2-hour Postprandial Insulin (pmol/L)']) * 24

# %%
# Separating data for male and female patients
male_data = df3[df3['Gender (Female=1, Male=2)'] == 2]
female_data = df3[df3['Gender (Female=1, Male=2)'] == 1]

# %%
# Calculating mean BMI for male and female patients to show functional use of gendered data.
mean_bmi_male = male_data['BMI (kg/m2)'].mean()
mean_bmi_female = female_data['BMI (kg/m2)'].mean()

print("Mean BMI for male patients:", mean_bmi_male)
print("Mean BMI for female patients:", mean_bmi_female)
# Out:
# Mean BMI for male patients: 23.74977607862903
# Mean BMI for female patients: 23.688884664533493

# %%
# Plotting BMI distribution

plt.figure(figsize=(8, 6))
plt.hist(df3['BMI Category'], bins=20, color='b', edgecolor='k')
plt.title('BMI Distribution of Patients')
plt.xlabel('BMI (kg/m2)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Plotting BMI distribution for male and female patients
plt.figure(figsize=(10, 6))
plt.hist(male_data['BMI Category'], bins=20, color='green', alpha=0.5, label='Male', edgecolor='black')
plt.hist(female_data['BMI Category'], bins=20, color='blue', alpha=0.5, label='Female', edgecolor='black')
plt.title('BMI Distribution of Patients by Gender')
plt.xlabel('BMI (kg/m2)')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
Look up the means to show progress of treatment from day one BMI versus end of study
